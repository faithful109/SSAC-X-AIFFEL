# %%
# PIL 라이브러리가 설치되어 있지 않다면 설치
# !pip install pillow   

from PIL import Image
import os, glob
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

print("PIL 라이브러리 import 완료!")


#데이서셑 불러오기
def load_data(img_path):
    # 가위 : 0, 바위 : 1, 보 : 2
    number_of_data=3600   # 가위바위보 이미지 개수 총합에 주의하세요.
    img_size=28
    color=3
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/scissor/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0   # 가위 : 0
        idx=idx+1

    for file in glob.iglob(img_path+'/rock/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   # 바위 : 1
        idx=idx+1       
    
    for file in glob.iglob(img_path+'/paper/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2   # 보 : 2
        idx=idx+1
        
    print("학습데이터(x_train)의 이미지 개수는",idx,"입니다.")
    return imgs, labels

image_dir_path = os.getenv("HOME") + "/aiffel/train1200"
(x_train, y_train)=load_data(image_dir_path)
x_train_norm = x_train/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))


#데이터가 잘 불러와졌는지 이미지 불러오기
#plt.imshow(x_train[0])
#print('라벨: ', y_train[0])


# model을 직접 만들어 보세요.
print(len(x_train))  # x_train 배열의 크기를 출력
print(x_train.shape)

model=keras.models.Sequential()
model.add(keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,3)))
model.add(keras.layers.MaxPool2D(2,2))
model.add(keras.layers.Conv2D(64, (3,3), activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(3, activation='softmax'))

model.summary()


# model을 학습
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.fit(x_train, y_train, epochs=20)



# x_test, y_test를 만들기
def load_data(img_path):
    # 가위 : 0, 바위 : 1, 보 : 2
    number_of_data=300   # 가위바위보 이미지 개수 총합에 주의하세요.
    img_size=28
    color=3
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/scissor/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0   # 가위 : 0
        idx=idx+1

    for file in glob.iglob(img_path+'/rock/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   # 바위 : 1
        idx=idx+1       
    
    for file in glob.iglob(img_path+'/paper/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2   # 보 : 2
        idx=idx+1
        
    print("테스트데이터(x_test)의 이미지 개수는",idx,"입니다.")
    return imgs, labels

image_dir_path = os.getenv("HOME") + "/aiffel/test4"
(x_test, y_test)=load_data(image_dir_path)
x_test_norm = x_test/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_test shape: {}".format(x_test.shape))
print("y_test shape: {}".format(y_test.shape))


# model을 테스트 데이터로 평가
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print("test_loss: {} ".format(test_loss))
print("test_accuracy: {}".format(test_accuracy))
# Out:
# Requirement already satisfied: pillow in ./anaconda3/envs/aiffel/lib/python3.7/site-packages (8.0.1)
# PIL 라이브러리 import 완료!
# 학습데이터(x_train)의 이미지 개수는 3600 입니다.
# x_train shape: (3600, 28, 28, 3)
# y_train shape: (3600,)
# 3600
# (3600, 28, 28, 3)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 64)        1792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                51232
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 90,051
# Trainable params: 90,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 113/113 [==============================] - 0s 2ms/step - loss: 2.3368 - accuracy: 0.3464
# Epoch 2/20
# 113/113 [==============================] - 0s 2ms/step - loss: 1.0330 - accuracy: 0.4344
# Epoch 3/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.9700 - accuracy: 0.4903
# Epoch 4/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.9459 - accuracy: 0.4981
# Epoch 5/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.9063 - accuracy: 0.5261
# Epoch 6/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.8506 - accuracy: 0.5575
# Epoch 7/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.7954 - accuracy: 0.6092
# Epoch 8/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.7464 - accuracy: 0.6383
# Epoch 9/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.5906 - accuracy: 0.7214
# Epoch 10/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.4773 - accuracy: 0.7786
# Epoch 11/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8517
# Epoch 12/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3180 - accuracy: 0.8717
# Epoch 13/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9297
# Epoch 14/20
# 113/113 [==============================] - 0s 3ms/step - loss: 0.1590 - accuracy: 0.9483
# Epoch 15/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9667
# Epoch 16/20
# 113/113 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9656
# Epoch 17/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9661
# Epoch 18/20
# 113/113 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9831
# Epoch 19/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 0.9914
# Epoch 20/20
# 113/113 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9903
# 테스트데이터(x_test)의 이미지 개수는 300 입니다.
# x_test shape: (300, 28, 28, 3)
# y_test shape: (300,)
# 10/10 - 0s - loss: 1.7249 - accuracy: 0.7333
# test_loss: 1.7248787879943848
# test_accuracy: 0.7333333492279053
